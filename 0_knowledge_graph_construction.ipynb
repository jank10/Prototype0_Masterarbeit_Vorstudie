# %% [markdown]
# ## Knowledge Graph Construction
#
# The purpose of this notebook is to enable anyone to populate the sample knowledge graph which is used to implement Prototype0.
#
# The following code can be run to either populate a neo4j AuraDB instance or a containerized neo4j instance by running the docker-compose.yaml file. <br>
# Before running the code in this notebook, make sure that you have instantiated one of the two options.
#
# A .env with the following content needs to be present: <br>
# - NEO4J_URI = "bolt://localhost:7687"<br>
# - NEO4J_USERNAME = "neo4j"<br>
# - NEO4J_PASSWORD = "your_password"<br>

# %%
import os
from dotenv import load_dotenv
from neo4j import GraphDatabase

# %%
# Load environment variables
load_dotenv()

# Neo4j configuration & constraints
neo4j_uri = os.getenv("NEO4J_URI")
neo4j_user = os.getenv("NEO4J_USERNAME")
neo4j_password = os.getenv("NEO4J_PASSWORD")

# %% [markdown]
# #### Helper Function to execute cypher from a file

# %%
def execute_cypher_file(driver, file_path):
    with open(file_path, "r") as file:
        # Read the file and split statements by semicolon
        cypher_statements = file.read().split(";")
    
    with driver.session() as session:
        print(f"Executing Cypher file: {file_path}")
        for statement in cypher_statements:
            if statement.strip():  # Skip empty statements
                print(f"Executing: {statement.strip()}")
                session.run(statement.strip())
        print(f"Successfully executed: {file_path}")

# %% [markdown]
# #### Function to populate the knowledge graph

# %%
def populate_knowledge_graph():
    # The files are sorted in the order which is needed to construct the KG
    cypher_files = [
        "cypher_statements/teams.txt",
        "cypher_statements/persons.txt",
        "cypher_statements/reporting_structure.txt",
        "cypher_statements/emails.txt",
        "cypher_statements/chats.txt",
        "cypher_statements/documents.txt",
    ]

    driver = GraphDatabase.driver(neo4j_uri, auth=(neo4j_user, neo4j_password))

    try:
        for file_path in cypher_files:
            if os.path.exists(file_path):
                execute_cypher_file(driver, file_path)
            else:
                print(f"File not found: {file_path}")
    except Exception as e:
        print(f"Error occurred populating the knowledge graph: {e}")
    finally:
        driver.close()

# %% [markdown]
# #### Execute code

# %%
populate_knowledge_graph()
# Out:
# Executing Cypher file: cypher_statements/teams.txt
# Executing: CREATE (team1:Team {id: 1, name: "Sales", department_head: "Michael Adams"})
# Executing: CREATE (team2:Team {id: 2, name: "Accounting", department_head: "Linda Chen"})
# Executing: CREATE (team3:Team {id: 3, name: "Account Management", department_head: "Raj Patel"})
# Executing: CREATE (team4:Team {id: 4, name: "Legal", department_head: "Samantha Green"})
# Executing: CREATE (team5:Team {id: 5, name: "Marketing", department_head: "Chris Taylor"})
# Executing: CREATE (team6:Team {id: 6, name: "IT", department_head: "Nina Williams"})
# Successfully executed: cypher_statements/teams.txt
# Executing Cypher file: cypher_statements/persons.txt
# Executing: CREATE (p1:Person {id: 1, name: "Michael Adams", role: "Head of Sales", team: "Sales"})
# Executing: CREATE (p2:Person {id: 2, name: "Karen Lee", role: "Sales Associate", team: "Sales"})
# Executing: CREATE (p3:Person {id: 3, name: "Linda Chen", role: "Head of Accounting", team: "Accounting"})
# Executing: CREATE (p4:Person {id: 4, name: "Tom Wilson", role: "Accountant", team: "Accounting"})
# Executing: CREATE (p5:Person {id: 5, name: "Raj Patel", role: "Head of Account Management", team: "Account Management"})
# Executing: CREATE (p6:Person {id: 6, name: "Alicia Gomez", role: "Account Manager", team: "Account Management"})
# Executing: CREATE (p7:Person {id: 7, name: "Samantha Green", role: "Head of Legal", team: "Legal"})
# Executing: CREATE (p8:Person {id: 8, name: "Danielle Brown", role: "Legal Associate", team: "Legal"})
# Executing: CREATE (p9:Person {id: 9, name: "Chris Taylor", role: "Head of Marketing", team: "Marketing"})
# Executing: CREATE (p10:Person {id: 10, name: "Mark Evans", role: "Marketing Specialist", team: "Marketing"})
# Executing: CREATE (p11:Person {id: 11, name: "Nina Williams", role: "Head of IT", team: "IT"})
# Executing: CREATE (p12:Person {id: 12, name: "Roberto Diaz", role: "IT Specialist", team: "IT"})
# Executing: CREATE (p13:Person {id: 13, name: "David Johnson", role: "Sales Associate", team: "Sales"})
# Executing: CREATE (p14:Person {id: 14, name: "Emily Davis", role: "Accountant", team: "Accounting"})
# Executing: CREATE (p15:Person {id: 15, name: "Daniel Roberts", role: "Account Manager", team: "Account Management"})
# Executing: CREATE (p16:Person {id: 16, name: "Jessica Brown", role: "Legal Associate", team: "Legal"})
# Executing: CREATE (p17:Person {id: 17, name: "Anthony Wright", role: "Marketing Specialist", team: "Marketing"})
# Executing: CREATE (p18:Person {id: 18, name: "Stephanie White", role: "IT Support", team: "IT"})
# Executing: CREATE (p19:Person {id: 19, name: "Paul Martinez", role: "Sales Associate", team: "Sales"})
# Executing: CREATE (p20:Person {id: 20, name: "Rachel Green", role: "Account Manager", team: "Account Management"})
# Executing: CREATE (p21:Person {id: 21, name: "George Harris", role: "Legal Associate", team: "Legal"})
# Executing: CREATE (p22:Person {id: 22, name: "Amanda Lopez", role: "Marketing Specialist", team: "Marketing"})
# Executing: CREATE (p23:Person {id: 23, name: "Eric Nelson", role: "IT Specialist", team: "IT"})
# Executing: CREATE (p24:Person {id: 24, name: "Patricia Collins", role: "Accountant", team: "Accounting"})
# Executing: CREATE (p25:Person {id: 25, name: "Mark Fisher", role: "Sales Manager", team: "Sales"})
# Executing: CREATE (p26:Person {id: 26, name: "Susan Gray", role: "Legal Counsel", team: "Legal"})
# Executing: CREATE (p27:Person {id: 27, name: "Kevin Brown", role: "Marketing Manager", team: "Marketing"})
# Executing: CREATE (p28:Person {id: 28, name: "Laura Peterson", role: "IT Support", team: "IT"})
# Executing: CREATE (p29:Person {id: 29, name: "Nancy Taylor", role: "Account Manager", team: "Account Management"})
# Executing: CREATE (p30:Person {id: 30, name: "Ethan Brooks", role: "Sales Manager", team: "Sales"})
# Executing: MATCH (p:Person {name: "Michael Adams"}), (t:Team {name: "Sales"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (t:Team {name: "Sales"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (t:Team {name: "Accounting"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (t:Team {name: "Accounting"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Raj Patel"}), (t:Team {name: "Account Management"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (t:Team {name: "Account Management"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (t:Team {name: "Legal"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Danielle Brown"}), (t:Team {name: "Legal"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (t:Team {name: "Marketing"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Mark Evans"}), (t:Team {name: "Marketing"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Nina Williams"}), (t:Team {name: "IT"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Roberto Diaz"}), (t:Team {name: "IT"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "David Johnson"}), (t:Team {name: "Sales"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (t:Team {name: "Accounting"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Daniel Roberts"}), (t:Team {name: "Account Management"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (t:Team {name: "Legal"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Anthony Wright"}), (t:Team {name: "Marketing"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Stephanie White"}), (t:Team {name: "IT"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Paul Martinez"}), (t:Team {name: "Sales"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (t:Team {name: "Account Management"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "George Harris"}), (t:Team {name: "Legal"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (t:Team {name: "Marketing"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (t:Team {name: "IT"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (t:Team {name: "Accounting"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Mark Fisher"}), (t:Team {name: "Sales"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Susan Gray"}), (t:Team {name: "Legal"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (t:Team {name: "Marketing"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (t:Team {name: "IT"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Nancy Taylor"}), (t:Team {name: "Account Management"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Ethan Brooks"}), (t:Team {name: "Sales"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: CREATE (ceo:Person {id: 31, name: "Alex Morgan", role: "CEO", team: "Executive"})
# Executing: CREATE (team_exec:Team {id: 7, name: "Executive", department_head: "Alex Morgan"})
# Executing: MATCH (p:Person {name: "Alex Morgan"}), (t:Team {name: "Executive"}) MERGE (p)-[:BELONGS_TO]->(t)
# Executing: MATCH (p:Person {name: "Alex Morgan"}), (d:Person {name: "Michael Adams"}) MERGE (p)-[:REPORTS_TO]->(d)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (ceo:Person {name: "Alex Morgan"}) MERGE (p)-[:REPORTS_TO]->(ceo)
# Executing: MATCH (p:Person {name: "Raj Patel"}), (ceo:Person {name: "Alex Morgan"}) MERGE (p)-[:REPORTS_TO]->(ceo)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (ceo:Person {name: "Alex Morgan"}) MERGE (p)-[:REPORTS_TO]->(ceo)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (ceo:Person {name: "Alex Morgan"}) MERGE (p)-[:REPORTS_TO]->(ceo)
# Executing: MATCH (p:Person {name: "Nina Williams"}), (ceo:Person {name: "Alex Morgan"}) MERGE (p)-[:REPORTS_TO]->(ceo)
# Successfully executed: cypher_statements/persons.txt
# Executing Cypher file: cypher_statements/reporting_structure.txt
# Executing: MATCH (p1:Person {name: "Karen Lee"}), (p2:Person {name: "Michael Adams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "David Johnson"}), (p2:Person {name: "Michael Adams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Paul Martinez"}), (p2:Person {name: "Michael Adams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Mark Fisher"}), (p2:Person {name: "Michael Adams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Ethan Brooks"}), (p2:Person {name: "Michael Adams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p3:Person {name: "Tom Wilson"}), (p4:Person {name: "Linda Chen"}) MERGE (p3)-[:REPORTS_TO]->(p4)
# Executing: MATCH (p1:Person {name: "Emily Davis"}), (p2:Person {name: "Linda Chen"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Patricia Collins"}), (p2:Person {name: "Linda Chen"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Alicia Gomez"}), (p2:Person {name: "Raj Patel"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Daniel Roberts"}), (p2:Person {name: "Raj Patel"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Rachel Green"}), (p2:Person {name: "Raj Patel"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Nancy Taylor"}), (p2:Person {name: "Raj Patel"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Danielle Brown"}), (p2:Person {name: "Samantha Green"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Jessica Brown"}), (p2:Person {name: "Samantha Green"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "George Harris"}), (p2:Person {name: "Samantha Green"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Susan Gray"}), (p2:Person {name: "Samantha Green"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Mark Evans"}), (p2:Person {name: "Chris Taylor"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Anthony Wright"}), (p2:Person {name: "Chris Taylor"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Amanda Lopez"}), (p2:Person {name: "Chris Taylor"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Kevin Brown"}), (p2:Person {name: "Chris Taylor"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Roberto Diaz"}), (p2:Person {name: "Nina Williams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Stephanie White"}), (p2:Person {name: "Nina Williams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Eric Nelson"}), (p2:Person {name: "Nina Williams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Executing: MATCH (p1:Person {name: "Laura Peterson"}), (p2:Person {name: "Nina Williams"}) MERGE (p1)-[:REPORTS_TO]->(p2)
# Successfully executed: cypher_statements/reporting_structure.txt
# Executing Cypher file: cypher_statements/emails.txt
# Executing: CREATE (email1:email_message {id: 1, timestamp: "2024-03-01T08:30:00", subject_line: "Team Meeting", content: "Please join the meeting at 10 AM.", sender: "Michael Adams", recipient: "Karen Lee"})
# Executing: CREATE (email2:email_message {id: 2, timestamp: "2024-03-02T09:00:00", subject_line: "Budget Review", content: "The review is scheduled for next Monday.", sender: "Linda Chen", recipient: "Tom Wilson"})
# Executing: CREATE (email3:email_message {id: 3, timestamp: "2024-03-03T10:45:00", subject_line: "Client Account Update", content: "Here is the latest update on the client account.", sender: "Raj Patel", recipient: "Alicia Gomez"})
# Executing: CREATE (email4:email_message {id: 4, timestamp: "2024-03-04T14:20:00", subject_line: "Legal Policy Update", content: "Please review the attached policy updates.", sender: "Samantha Green", recipient: "Danielle Brown"})
# CREATE (email5:email_message {id: 5, timestamp: "2024-03-05T15:30:00", subject_line: "Marketing Campaign Planning", content: "Let's schedule a meeting to discuss the upcoming campaign.", sender: "Chris Taylor", recipient: "Mark Evans"})
# Executing: CREATE (email6:email_message {id: 6, timestamp: "2024-03-06T08:00:00", subject_line: "System Maintenance Alert", content: "The IT system will undergo maintenance tonight.", sender: "Nina Williams", recipient: "Roberto Diaz"})
# Executing: CREATE (email7:email_message {id: 7, timestamp: "2024-03-07T13:45:00", subject_line: "Sales Forecast", content: "Please review the updated sales forecast for Q2.", sender: "Michael Adams", recipient: "Paul Martinez"})
# Executing: CREATE (email8:email_message {id: 8, timestamp: "2024-03-08T10:30:00", subject_line: "Expense Report Submission", content: "Please submit your expense reports by end of day.", sender: "Emily Davis", recipient: "Patricia Collins"})
# Executing: CREATE (email9:email_message {id: 9, timestamp: "2024-03-09T09:15:00", subject_line: "Client Onboarding Process", content: "Here are the steps for onboarding the new client.", sender: "Alicia Gomez", recipient: "Rachel Green"})
# Executing: CREATE (email10:email_message {id: 10, timestamp: "2024-03-10T11:00:00", subject_line: "Q1 Legal Report", content: "Please find the Q1 legal report attached.", sender: "Danielle Brown", recipient: "George Harris"})
# Executing: CREATE (email11:email_message {id: 11, timestamp: "2024-03-11T08:50:00", subject_line: "Product Launch Details", content: "Details for the product launch are attached.", sender: "Kevin Brown", recipient: "Amanda Lopez"})
# Executing: CREATE (email12:email_message {id: 12, timestamp: "2024-03-12T14:35:00", subject_line: "System Security Update", content: "Here are the latest security measures implemented.", sender: "Roberto Diaz", recipient: "Laura Peterson"})
# Executing: CREATE (email13:email_message {id: 13, timestamp: "2024-03-13T09:00:00", subject_line: "Sales Training Feedback", content: "Please provide feedback on the recent training session.", sender: "Karen Lee", recipient: "David Johnson"})
# Executing: CREATE (email14:email_message {id: 14, timestamp: "2024-03-14T10:20:00", subject_line: "Budget Proposal Review", content: "The budget proposal needs to be finalized by Friday.", sender: "Linda Chen", recipient: "Tom Wilson"})
# Executing: CREATE (email15:email_message {id: 15, timestamp: "2024-03-15T15:10:00", subject_line: "Customer Engagement Strategies", content: "Let's discuss our customer engagement initiatives.", sender: "Rachel Green", recipient: "Nancy Taylor"})
# Executing: CREATE (email16:email_message {id: 16, timestamp: "2024-03-16T13:30:00", subject_line: "IT Support Procedures", content: "Please review the updated IT support procedures.", sender: "Laura Peterson", recipient: "Stephanie White"})
# Executing: CREATE (email17:email_message {id: 17, timestamp: "2024-03-17T08:45:00", subject_line: "Marketing Campaign Results", content: "Here are the results of our recent marketing campaign.", sender: "Mark Evans", recipient: "Anthony Wright"})
# Executing: CREATE (email18:email_message {id: 18, timestamp: "2024-03-18T09:30:00", subject_line: "New Hire Orientation", content: "Please welcome our new hires during orientation.", sender: "Patricia Collins", recipient: "Emily Davis"})
# Executing: CREATE (email19:email_message {id: 19, timestamp: "2024-03-19T10:15:00", subject_line: "Financial Audit Preparation", content: "Prepare all necessary documents for the audit.", sender: "Tom Wilson", recipient: "Linda Chen"})
# Executing: CREATE (email20:email_message {id: 20, timestamp: "2024-03-20T12:20:00", subject_line: "Legal Case Update", content: "The legal case status has been updated.", sender: "George Harris", recipient: "Jessica Brown"})
# Executing: CREATE (email21:email_message {id: 21, timestamp: "2024-03-21T08:15:00", subject_line: "Infrastructure Upgrade Plan", content: "Please review the infrastructure upgrade plan.", sender: "Eric Nelson", recipient: "Nina Williams"})
# Executing: CREATE (email22:email_message {id: 22, timestamp: "2024-03-22T09:50:00", subject_line: "Sales Pipeline Review", content: "The sales pipeline data is available for review.", sender: "Paul Martinez", recipient: "Ethan Brooks"})
# Executing: CREATE (email23:email_message {id: 23, timestamp: "2024-03-23T10:35:00", subject_line: "Account Strategy Meeting", content: "We will have a meeting to finalize the strategy.", sender: "Daniel Roberts", recipient: "Nancy Taylor"})
# Executing: CREATE (email24:email_message {id: 24, timestamp: "2024-03-24T13:00:00", subject_line: "Employee Satisfaction Survey", content: "Please fill out the employee satisfaction survey.", sender: "Susan Gray", recipient: "Kevin Brown"})
# Executing: CREATE (email25:email_message {id: 25, timestamp: "2024-03-25T14:45:00", subject_line: "Marketing Metrics Review", content: "Review the marketing metrics and provide input.", sender: "Anthony Wright", recipient: "Chris Taylor"})
# Executing: CREATE (email26:email_message {id: 26, timestamp: "2024-03-26T11:00:00", subject_line: "Accounting Reconciliation", content: "The monthly reconciliation needs review.", sender: "Emily Davis", recipient: "Patricia Collins"})
# Executing: CREATE (email27:email_message {id: 27, timestamp: "2024-03-27T10:00:00", subject_line: "Legal Policy Draft", content: "Please review the draft of the new policy.", sender: "Jessica Brown", recipient: "Samantha Green"})
# Executing: CREATE (email28:email_message {id: 28, timestamp: "2024-03-28T09:40:00", subject_line: "Security Report", content: "Here is the quarterly IT security report.", sender: "Stephanie White", recipient: "Eric Nelson"})
# Executing: CREATE (email29:email_message {id: 29, timestamp: "2024-03-29T12:00:00", subject_line: "Product Feedback Summary", content: "Summarized feedback from customers.", sender: "Amanda Lopez", recipient: "Kevin Brown"})
# Executing: CREATE (email30:email_message {id: 30, timestamp: "2024-03-30T14:30:00", subject_line: "Growth Strategy Review", content: "Let's finalize the growth strategy for Q2.", sender: "Mark Fisher", recipient: "Paul Martinez"})
# Executing: CREATE (email31:email_message {id: 31, timestamp: "2024-04-01T10:00:00", subject_line: "Client Meeting Recap", content: "Summary of key points from our client meeting.", sender: "Alicia Gomez", recipient: "Daniel Roberts"})
# Executing: CREATE (email32:email_message {id: 32, timestamp: "2024-04-02T09:30:00", subject_line: "System Maintenance Update", content: "IT maintenance was completed successfully.", sender: "Nina Williams", recipient: "Laura Peterson"})
# Executing: CREATE (email33:email_message {id: 33, timestamp: "2024-04-03T13:20:00", subject_line: "Sales Metrics Analysis", content: "Reviewing Q1 sales metrics for key insights.", sender: "Michael Adams", recipient: "David Johnson"})
# Executing: CREATE (email34:email_message {id: 34, timestamp: "2024-04-04T14:10:00", subject_line: "Budget Approval Needed", content: "Please review and approve the proposed budget.", sender: "Linda Chen", recipient: "Tom Wilson"})
# Executing: CREATE (email35:email_message {id: 35, timestamp: "2024-04-05T08:50:00", subject_line: "New Marketing Initiative", content: "Details on our new marketing initiative.", sender: "Chris Taylor", recipient: "Amanda Lopez"})
# Executing: CREATE (email36:email_message {id: 36, timestamp: "2024-04-06T11:30:00", subject_line: "Legal Agreement Draft", content: "Draft of the new legal agreement for your review.", sender: "Jessica Brown", recipient: "George Harris"})
# Executing: CREATE (email37:email_message {id: 37, timestamp: "2024-04-07T10:15:00", subject_line: "Customer Feedback on Services", content: "Feedback received from clients on our services.", sender: "Rachel Green", recipient: "Nancy Taylor"})
# Executing: CREATE (email38:email_message {id: 38, timestamp: "2024-04-08T13:40:00", subject_line: "IT Support Tickets Update", content: "Status update on all open IT support tickets.", sender: "Roberto Diaz", recipient: "Eric Nelson"})
# Executing: CREATE (email39:email_message {id: 39, timestamp: "2024-04-09T14:25:00", subject_line: "Upcoming Sales Training", content: "Details of the upcoming sales training event.", sender: "Karen Lee", recipient: "Paul Martinez"})
# Executing: CREATE (email40:email_message {id: 40, timestamp: "2024-04-10T09:05:00", subject_line: "Q2 Marketing Plan", content: "Overview of our Q2 marketing strategy.", sender: "Mark Evans", recipient: "Kevin Brown"})
# Executing: CREATE (email41:email_message {id: 41, timestamp: "2024-04-11T12:50:00", subject_line: "Quarterly Financial Report", content: "The quarterly financial report is attached.", sender: "Tom Wilson", recipient: "Linda Chen"})
# Executing: CREATE (email42:email_message {id: 42, timestamp: "2024-04-12T08:00:00", subject_line: "Client Contract Review", content: "Review and provide feedback on the attached client contract.", sender: "Samantha Green", recipient: "Danielle Brown"})
# Executing: CREATE (email43:email_message {id: 43, timestamp: "2024-04-13T10:45:00", subject_line: "Marketing Event Planning", content: "Meeting to discuss planning for the next event.", sender: "Anthony Wright", recipient: "Chris Taylor"})
# Executing: CREATE (email44:email_message {id: 44, timestamp: "2024-04-14T09:20:00", subject_line: "Security System Audit", content: "Audit results and recommendations for the security system.", sender: "Stephanie White", recipient: "Eric Nelson"})
# Executing: CREATE (email45:email_message {id: 45, timestamp: "2024-04-15T14:00:00", subject_line: "Q1 Sales Report", content: "Sales performance and highlights from Q1.", sender: "Ethan Brooks", recipient: "Michael Adams"})
# Executing: CREATE (email46:email_message {id: 46, timestamp: "2024-04-16T13:15:00", subject_line: "Internal Team Meeting", content: "Agenda for the internal team meeting.", sender: "Rachel Green", recipient: "Nancy Taylor"})
# Executing: CREATE (email47:email_message {id: 47, timestamp: "2024-04-17T11:10:00", subject_line: "Marketing Content Creation", content: "Please review the draft marketing content.", sender: "Kevin Brown", recipient: "Amanda Lopez"})
# Executing: CREATE (email48:email_message {id: 48, timestamp: "2024-04-18T09:30:00", subject_line: "IT Upgrade Timeline", content: "Updated timeline for planned IT upgrades.", sender: "Laura Peterson", recipient: "Nina Williams"})
# Executing: CREATE (email49:email_message {id: 49, timestamp: "2024-04-19T15:20:00", subject_line: "Sales Incentive Program Update", content: "Details on the updated sales incentive program.", sender: "David Johnson", recipient: "Karen Lee"})
# Executing: CREATE (email50:email_message {id: 50, timestamp: "2024-04-20T12:45:00", subject_line: "Legal Compliance Requirements", content: "Updated compliance requirements for review.", sender: "George Harris", recipient: "Samantha Green"})
# Executing: CREATE (email51:email_message {id: 51, timestamp: "2024-04-21T10:40:00", subject_line: "Q2 Financial Goals", content: "Financial targets for Q2 are outlined here.", sender: "Linda Chen", recipient: "Tom Wilson"})
# Executing: CREATE (email52:email_message {id: 52, timestamp: "2024-04-22T09:50:00", subject_line: "Customer Onboarding Workflow", content: "Revised workflow for customer onboarding.", sender: "Alicia Gomez", recipient: "Daniel Roberts"})
# Executing: CREATE (email53:email_message {id: 53, timestamp: "2024-04-23T14:30:00", subject_line: "Marketing Campaign Performance", content: "Insights on the recent marketing campaign.", sender: "Mark Evans", recipient: "Chris Taylor"})
# Executing: CREATE (email54:email_message {id: 54, timestamp: "2024-04-24T13:00:00", subject_line: "Client Account Details", content: "Updated account information for key clients.", sender: "Raj Patel", recipient: "Alicia Gomez"})
# Executing: CREATE (email55:email_message {id: 55, timestamp: "2024-04-25T11:20:00", subject_line: "IT System Maintenance Schedule", content: "Planned maintenance schedule for IT systems.", sender: "Roberto Diaz", recipient: "Eric Nelson"})
# Executing: CREATE (email56:email_message {id: 56, timestamp: "2024-04-26T10:15:00", subject_line: "Legal Policy Review", content: "Review the attached legal policies.", sender: "Susan Gray", recipient: "Jessica Brown"})
# Executing: CREATE (email57:email_message {id: 57, timestamp: "2024-04-27T09:05:00", subject_line: "Q2 Sales Goals", content: "Goals for Q2 sales targets.", sender: "Paul Martinez", recipient: "Ethan Brooks"})
# Executing: CREATE (email58:email_message {id: 58, timestamp: "2024-04-28T14:10:00", subject_line: "Marketing Strategy Session", content: "Session agenda for discussing marketing strategies.", sender: "Amanda Lopez", recipient: "Anthony Wright"})
# Executing: CREATE (email59:email_message {id: 59, timestamp: "2024-04-29T08:45:00", subject_line: "IT Security Review", content: "Review findings from the latest security audit.", sender: "Stephanie White", recipient: "Laura Peterson"})
# Executing: CREATE (email60:email_message {id: 60, timestamp: "2024-04-30T13:40:00", subject_line: "Employee Training Program", content: "Details on upcoming training sessions.", sender: "Patricia Collins", recipient: "Emily Davis"})
# Executing: CREATE (email61:email_message {id: 61, timestamp: "2024-05-01T09:30:00", subject_line: "Sales Strategy Update", content: "Updated strategy for the upcoming quarter.", sender: "Michael Adams", recipient: "Mark Fisher"})
# Executing: CREATE (email62:email_message {id: 62, timestamp: "2024-05-02T10:55:00", subject_line: "Budget Allocation Approval", content: "Please approve the budget allocations.", sender: "Linda Chen", recipient: "Tom Wilson"})
# Executing: CREATE (email63:email_message {id: 63, timestamp: "2024-05-03T14:25:00", subject_line: "Client Account Status", content: "Current status of our key accounts.", sender: "Alicia Gomez", recipient: "Rachel Green"})
# Executing: CREATE (email64:email_message {id: 64, timestamp: "2024-05-04T12:20:00", subject_line: "New Product Launch", content: "Launch details for the upcoming product.", sender: "Chris Taylor", recipient: "Kevin Brown"})
# Executing: CREATE (email65:email_message {id: 65, timestamp: "2024-05-05T10:10:00", subject_line: "Legal Review Session", content: "Agenda for the legal review session.", sender: "Samantha Green", recipient: "Jessica Brown"})
# Executing: CREATE (email66:email_message {id: 66, timestamp: "2024-05-06T08:40:00", subject_line: "Quarterly IT Updates", content: "Highlights of IT system changes.", sender: "Eric Nelson", recipient: "Roberto Diaz"})
# Executing: CREATE (email67:email_message {id: 67, timestamp: "2024-05-07T13:50:00", subject_line: "Sales Performance Metrics", content: "Metrics for last quarter's sales performance.", sender: "Paul Martinez", recipient: "Karen Lee"})
# Executing: CREATE (email68:email_message {id: 68, timestamp: "2024-05-08T09:55:00", subject_line: "Marketing Plan Review", content: "Plan review for the next marketing cycle.", sender: "Mark Evans", recipient: "Amanda Lopez"})
# Executing: CREATE (email69:email_message {id: 69, timestamp: "2024-05-09T11:30:00", subject_line: "Internal Audit Follow-up", content: "Follow-up actions required post-audit.", sender: "Emily Davis", recipient: "Linda Chen"})
# Executing: CREATE (email70:email_message {id: 70, timestamp: "2024-05-10T14:20:00", subject_line: "Client Retention Strategies", content: "Discuss strategies for client retention.", sender: "Rachel Green", recipient: "Nancy Taylor"})
# Executing: CREATE (email71:email_message {id: 71, timestamp: "2024-05-11T13:10:00", subject_line: "Sales Opportunity Planning", content: "Meeting to plan key sales opportunities.", sender: "Ethan Brooks", recipient: "Paul Martinez"})
# Executing: CREATE (email72:email_message {id: 72, timestamp: "2024-05-12T12:35:00", subject_line: "IT Infrastructure Upgrade", content: "Upgrade details for our IT infrastructure.", sender: "Laura Peterson", recipient: "Nina Williams"})
# Executing: CREATE (email73:email_message {id: 73, timestamp: "2024-05-13T09:00:00", subject_line: "Employee Performance Review", content: "Schedule for upcoming performance reviews.", sender: "Patricia Collins", recipient: "Emily Davis"})
# Executing: CREATE (email74:email_message {id: 74, timestamp: "2024-05-14T10:45:00", subject_line: "Legal Updates and Changes", content: "Summary of recent legal changes.", sender: "Jessica Brown", recipient: "Samantha Green"})
# Executing: CREATE (email75:email_message {id: 75, timestamp: "2024-05-15T15:30:00", subject_line: "Q2 Budget Proposal", content: "Details for the Q2 budget proposal.", sender: "Linda Chen", recipient: "Tom Wilson"})
# Executing: CREATE (email76:email_message {id: 76, timestamp: "2024-05-16T08:15:00", subject_line: "Sales Recap Meeting", content: "Summary of the sales recap meeting.", sender: "Michael Adams", recipient: "David Johnson"})
# Executing: CREATE (email77:email_message {id: 77, timestamp: "2024-05-17T13:25:00", subject_line: "Marketing Strategy Planning", content: "Planning for upcoming marketing strategies.", sender: "Chris Taylor", recipient: "Anthony Wright"})
# Executing: CREATE (email78:email_message {id: 78, timestamp: "2024-05-18T14:00:00", subject_line: "Client Relationship Management", content: "Managing key client relationships effectively.", sender: "Alicia Gomez", recipient: "Daniel Roberts"})
# Executing: CREATE (email79:email_message {id: 79, timestamp: "2024-05-19T09:45:00", subject_line: "IT System Security Enhancements", content: "Plan for enhancing system security.", sender: "Roberto Diaz", recipient: "Eric Nelson"})
# Executing: CREATE (email80:email_message {id: 80, timestamp: "2024-05-20T12:10:00", subject_line: "Customer Onboarding Review", content: "Reviewing the customer onboarding process.", sender: "Rachel Green", recipient: "Nancy Taylor"})
# Executing: CREATE (email81:email_message {id: 81, timestamp: "2024-05-21T11:20:00", subject_line: "Sales Growth Plan", content: "Strategies to boost sales growth.", sender: "David Johnson", recipient: "Karen Lee"})
# Executing: CREATE (email82:email_message {id: 82, timestamp: "2024-05-22T09:40:00", subject_line: "Marketing Content Approval", content: "Approval needed for the new marketing content.", sender: "Kevin Brown", recipient: "Mark Evans"})
# Executing: CREATE (email83:email_message {id: 83, timestamp: "2024-05-23T08:55:00", subject_line: "Budget Adjustment Request", content: "Request for budget adjustments.", sender: "Linda Chen", recipient: "Tom Wilson"})
# Executing: CREATE (email84:email_message {id: 84, timestamp: "2024-05-24T13:15:00", subject_line: "IT System Upgrade Status", content: "Status update on the system upgrade.", sender: "Laura Peterson", recipient: "Nina Williams"})
# Executing: CREATE (email85:email_message {id: 85, timestamp: "2024-05-25T10:05:00", subject_line: "Legal Case Briefing", content: "Briefing on the latest legal case developments.", sender: "George Harris", recipient: "Samantha Green"})
# Executing: CREATE (email86:email_message {id: 86, timestamp: "2024-05-26T12:00:00", subject_line: "Marketing Event Follow-up", content: "Follow-up actions post-marketing event.", sender: "Amanda Lopez", recipient: "Chris Taylor"})
# Executing: CREATE (email87:email_message {id: 87, timestamp: "2024-05-27T14:35:00", subject_line: "Client Proposal Review", content: "Review the client proposal draft.", sender: "Raj Patel", recipient: "Alicia Gomez"})
# Executing: CREATE (email88:email_message {id: 88, timestamp: "2024-05-28T09:25:00", subject_line: "IT Maintenance Log", content: "Log of recent maintenance activities.", sender: "Roberto Diaz", recipient: "Eric Nelson"})
# Executing: CREATE (email89:email_message {id: 89, timestamp: "2024-05-29T13:40:00", subject_line: "Sales Target Adjustment", content: "Proposed adjustments to sales targets.", sender: "Paul Martinez", recipient: "Karen Lee"})
# Executing: CREATE (email90:email_message {id: 90, timestamp: "2024-05-30T11:35:00", subject_line: "Performance Review Notes", content: "Notes from recent performance reviews.", sender: "Patricia Collins", recipient: "Emily Davis"})
# Executing: CREATE (email91:email_message {id: 91, timestamp: "2024-05-31T08:45:00", subject_line: "Client Engagement Metrics", content: "Metrics related to client engagement.", sender: "Rachel Green", recipient: "Nancy Taylor"})
# Executing: CREATE (email92:email_message {id: 92, timestamp: "2024-06-01T13:00:00", subject_line: "Q2 Financial Analysis", content: "Analysis of Q2 financial data.", sender: "Tom Wilson", recipient: "Linda Chen"})
# Executing: CREATE (email93:email_message {id: 93, timestamp: "2024-06-02T14:50:00", subject_line: "IT Security Training", content: "Schedule for IT security training sessions.", sender: "Stephanie White", recipient: "Laura Peterson"})
# Executing: CREATE (email94:email_message {id: 94, timestamp: "2024-06-03T09:10:00", subject_line: "Client Feedback Summary", content: "Summary of client feedback.", sender: "Alicia Gomez", recipient: "Daniel Roberts"})
# Executing: CREATE (email95:email_message {id: 95, timestamp: "2024-06-04T10:20:00", subject_line: "Sales Incentive Details", content: "Details of the sales incentive program.", sender: "Michael Adams", recipient: "Mark Fisher"})
# Executing: CREATE (email96:email_message {id: 96, timestamp: "2024-06-05T08:30:00", subject_line: "Budget Revision Request", content: "Request for revisions to the budget.", sender: "Linda Chen", recipient: "Tom Wilson"})
# Executing: CREATE (email97:email_message {id: 97, timestamp: "2024-06-06T15:15:00", subject_line: "Marketing Strategy Execution", content: "Details on executing the marketing strategy.", sender: "Chris Taylor", recipient: "Kevin Brown"})
# Executing: CREATE (email98:email_message {id: 98, timestamp: "2024-06-07T12:00:00", subject_line: "IT System Upgrade Plan", content: "Plan for upgrading our IT systems.", sender: "Nina Williams", recipient: "Eric Nelson"})
# Executing: CREATE (email99:email_message {id: 99, timestamp: "2024-06-08T10:40:00", subject_line: "Sales Performance Review", content: "Review of sales performance metrics.", sender: "Paul Martinez", recipient: "Ethan Brooks"})
# Executing: CREATE (email100:email_message {id: 100, timestamp: "2024-06-09T14:20:00", subject_line: "Client Relationship Review", content: "Review of client relationship management strategies.", sender: "Alicia Gomez", recipient: "Rachel Green"})
# Executing: MATCH (p:Person {name: "Michael Adams"}), (e:email_message {id: 1}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (e:email_message {id: 1}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (e:email_message {id: 2}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (e:email_message {id: 2}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Raj Patel"}), (e:email_message {id: 3}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (e:email_message {id: 3}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (e:email_message {id: 4}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Danielle Brown"}), (e:email_message {id: 4}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (e:email_message {id: 5}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Mark Evans"}), (e:email_message {id: 5}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Nina Williams"}), (e:email_message {id: 6}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Roberto Diaz"}), (e:email_message {id: 6}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Michael Adams"}), (e:email_message {id: 7}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Paul Martinez"}), (e:email_message {id: 7}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (e:email_message {id: 8}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (e:email_message {id: 8}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (e:email_message {id: 9}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (e:email_message {id: 9}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Danielle Brown"}), (e:email_message {id: 10}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "George Harris"}), (e:email_message {id: 10}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (e:email_message {id: 11}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (e:email_message {id: 11}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Roberto Diaz"}), (e:email_message {id: 12}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (e:email_message {id: 12}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (e:email_message {id: 13}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "David Johnson"}), (e:email_message {id: 13}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (e:email_message {id: 14}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (e:email_message {id: 14}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (e:email_message {id: 15}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Nancy Taylor"}), (e:email_message {id: 15}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (e:email_message {id: 16}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Stephanie White"}), (e:email_message {id: 16}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Mark Evans"}), (e:email_message {id: 17}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Anthony Wright"}), (e:email_message {id: 17}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (e:email_message {id: 18}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (e:email_message {id: 18}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (e:email_message {id: 19}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (e:email_message {id: 19}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "George Harris"}), (e:email_message {id: 20}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (e:email_message {id: 20}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (e:email_message {id: 21}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Nina Williams"}), (e:email_message {id: 21}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Paul Martinez"}), (e:email_message {id: 22}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Ethan Brooks"}), (e:email_message {id: 22}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Daniel Roberts"}), (e:email_message {id: 23}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Nancy Taylor"}), (e:email_message {id: 23}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Susan Gray"}), (e:email_message {id: 24}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (e:email_message {id: 24}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Anthony Wright"}), (e:email_message {id: 25}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (e:email_message {id: 25}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (e:email_message {id: 26}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (e:email_message {id: 26}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (e:email_message {id: 27}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (e:email_message {id: 27}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Stephanie White"}), (e:email_message {id: 28}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (e:email_message {id: 28}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (e:email_message {id: 29}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (e:email_message {id: 29}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Mark Fisher"}), (e:email_message {id: 30}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Paul Martinez"}), (e:email_message {id: 30}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (e:email_message {id: 31}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Daniel Roberts"}), (e:email_message {id: 31}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Nina Williams"}), (e:email_message {id: 32}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (e:email_message {id: 32}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Michael Adams"}), (e:email_message {id: 33}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "David Johnson"}), (e:email_message {id: 33}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (e:email_message {id: 34}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (e:email_message {id: 34}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (e:email_message {id: 35}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (e:email_message {id: 35}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (e:email_message {id: 36}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "George Harris"}), (e:email_message {id: 36}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (e:email_message {id: 37}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Nancy Taylor"}), (e:email_message {id: 37}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Roberto Diaz"}), (e:email_message {id: 38}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (e:email_message {id: 38}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (e:email_message {id: 39}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Paul Martinez"}), (e:email_message {id: 39}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Mark Evans"}), (e:email_message {id: 40}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (e:email_message {id: 40}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (e:email_message {id: 41}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (e:email_message {id: 41}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (e:email_message {id: 42}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Danielle Brown"}), (e:email_message {id: 42}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Anthony Wright"}), (e:email_message {id: 43}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (e:email_message {id: 43}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Stephanie White"}), (e:email_message {id: 44}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (e:email_message {id: 44}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Ethan Brooks"}), (e:email_message {id: 45}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Michael Adams"}), (e:email_message {id: 45}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (e:email_message {id: 46}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Nancy Taylor"}), (e:email_message {id: 46}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (e:email_message {id: 47}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (e:email_message {id: 47}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (e:email_message {id: 48}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Nina Williams"}), (e:email_message {id: 48}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "David Johnson"}), (e:email_message {id: 49}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (e:email_message {id: 49}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "George Harris"}), (e:email_message {id: 50}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (e:email_message {id: 50}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (e:email_message {id: 51}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (e:email_message {id: 51}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (e:email_message {id: 52}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Daniel Roberts"}), (e:email_message {id: 52}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Mark Evans"}), (e:email_message {id: 53}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (e:email_message {id: 53}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Raj Patel"}), (e:email_message {id: 54}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (e:email_message {id: 54}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Roberto Diaz"}), (e:email_message {id: 55}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (e:email_message {id: 55}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Susan Gray"}), (e:email_message {id: 56}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (e:email_message {id: 56}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Paul Martinez"}), (e:email_message {id: 57}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Ethan Brooks"}), (e:email_message {id: 57}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (e:email_message {id: 58}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Anthony Wright"}), (e:email_message {id: 58}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Stephanie White"}), (e:email_message {id: 59}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (e:email_message {id: 59}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (e:email_message {id: 60}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (e:email_message {id: 60}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Michael Adams"}), (e:email_message {id: 61}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Mark Fisher"}), (e:email_message {id: 61}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (e:email_message {id: 62}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (e:email_message {id: 62}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (e:email_message {id: 63}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (e:email_message {id: 63}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (e:email_message {id: 64}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (e:email_message {id: 64}) MERGE (p)-[:RECEIVED]->(e)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (e:email_message {id: 65}) MERGE (p)-[:WROTE]->(e)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (e:email_message {id: 65}) MERGE (p)-[:RECEIVED]->(e)
# ...
# Executing: CREATE (doc84:Document {id: 84, timestamp: "2025-01-05T14:25:00", document_name: "IT Training Manual", author: "Laura Peterson"})
# Executing: CREATE (doc85:Document {id: 85, timestamp: "2025-01-07T12:00:00", document_name: "Performance Appraisal Guidelines", author: "Kevin Brown"})
# Executing: CREATE (doc86:Document {id: 86, timestamp: "2025-01-09T09:35:00", document_name: "Employee Wellness Initiative", author: "Patricia Collins"})
# Executing: CREATE (doc87:Document {id: 87, timestamp: "2025-01-11T11:45:00", document_name: "Client Feedback Summary", author: "Nancy Taylor"})
# Executing: CREATE (doc88:Document {id: 88, timestamp: "2025-01-13T13:15:00", document_name: "Legal Memorandum", author: "Susan Gray"})
# Executing: CREATE (doc89:Document {id: 89, timestamp: "2025-01-15T08:30:00", document_name: "Sales Growth Metrics", author: "Ethan Brooks"})
# Executing: CREATE (doc90:Document {id: 90, timestamp: "2025-01-17T14:40:00", document_name: "Marketing Tactics Review", author: "Amanda Lopez"})
# Executing: CREATE (doc91:Document {id: 91, timestamp: "2025-01-19T09:20:00", document_name: "Quarterly Account Review", author: "Daniel Roberts"})
# Executing: CREATE (doc92:Document {id: 92, timestamp: "2025-01-21T15:00:00", document_name: "Legal Briefing Paper", author: "George Harris"})
# Executing: CREATE (doc93:Document {id: 93, timestamp: "2025-01-23T12:50:00", document_name: "IT Systems Audit", author: "Eric Nelson"})
# Executing: CREATE (doc94:Document {id: 94, timestamp: "2025-01-25T10:30:00", document_name: "Sales Team Handbook", author: "Karen Lee"})
# Executing: CREATE (doc95:Document {id: 95, timestamp: "2025-01-27T11:20:00", document_name: "Customer Retention Guide", author: "Raj Patel"})
# Executing: CREATE (doc96:Document {id: 96, timestamp: "2025-01-29T08:00:00", document_name: "Company Policies Update", author: "Jessica Brown"})
# Executing: CREATE (doc97:Document {id: 97, timestamp: "2025-02-01T14:15:00", document_name: "Market Opportunities Report", author: "Chris Taylor"})
# Executing: CREATE (doc98:Document {id: 98, timestamp: "2025-02-03T09:10:00", document_name: "Sales Target Analysis", author: "Mark Fisher"})
# Executing: CREATE (doc99:Document {id: 99, timestamp: "2025-02-05T15:50:00", document_name: "Q4 Revenue Breakdown", author: "Tom Wilson"})
# Executing: CREATE (doc100:Document {id: 100, timestamp: "2025-02-07T10:45:00", document_name: "Legal Risk Mitigation Plan", author: "Samantha Green"})
# Executing: MATCH (p:Person {name: "Michael Adams"}), (d:Document {document_name: "Q1 Sales Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (d:Document {document_name: "Budget Analysis"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Raj Patel"}), (d:Document {document_name: "Customer Account Summary"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (d:Document {document_name: "Legal Compliance Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (d:Document {document_name: "Marketing Strategy Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Nina Williams"}), (d:Document {document_name: "IT System Maintenance Guidelines"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Michael Adams"}), (d:Document {document_name: "Q2 Sales Forecast"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (d:Document {document_name: "Employee Expense Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (d:Document {document_name: "Client Onboarding Guidelines"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Danielle Brown"}), (d:Document {document_name: "Q1 Legal Review"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (d:Document {document_name: "Product Launch Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Roberto Diaz"}), (d:Document {document_name: "System Security Update"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (d:Document {document_name: "Sales Training Program"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (d:Document {document_name: "Q2 Budget Proposal"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (d:Document {document_name: "Customer Engagement Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (d:Document {document_name: "IT Helpdesk Procedures"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Mark Evans"}), (d:Document {document_name: "Marketing Campaign Results"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (d:Document {document_name: "New Hire Orientation Guide"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (d:Document {document_name: "Annual Financial Audit"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "George Harris"}), (d:Document {document_name: "Legal Case Summary"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (d:Document {document_name: "IT Infrastructure Upgrade Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Paul Martinez"}), (d:Document {document_name: "Sales Pipeline Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Daniel Roberts"}), (d:Document {document_name: "Account Management Strategy"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Susan Gray"}), (d:Document {document_name: "Employee Satisfaction Survey Results"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Anthony Wright"}), (d:Document {document_name: "Marketing Metrics Dashboard"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (d:Document {document_name: "Monthly Accounting Reconciliation"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (d:Document {document_name: "Legal Policy Update"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Stephanie White"}), (d:Document {document_name: "Quarterly IT Security Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (d:Document {document_name: "Product Feedback Analysis"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Mark Fisher"}), (d:Document {document_name: "Sales Growth Strategy"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Nancy Taylor"}), (d:Document {document_name: "Customer Retention Analysis"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Susan Gray"}), (d:Document {document_name: "Legal Risk Assessment"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (d:Document {document_name: "Marketing Content Calendar"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Nina Williams"}), (d:Document {document_name: "Annual IT Infrastructure Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Ethan Brooks"}), (d:Document {document_name: "Sales Opportunity Assessment"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (d:Document {document_name: "Customer Service Improvement Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (d:Document {document_name: "IT Cost Reduction Analysis"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (d:Document {document_name: "Competitor Analysis Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (d:Document {document_name: "Employee Training Guide"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (d:Document {document_name: "Budget Optimization Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Michael Adams"}), (d:Document {document_name: "Monthly Sales Summary"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (d:Document {document_name: "Customer Feedback Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (d:Document {document_name: "IT System Upgrade Proposal"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (d:Document {document_name: "New Product Launch Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Daniel Roberts"}), (d:Document {document_name: "Client Retention Strategy"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (d:Document {document_name: "Legal Compliance Checklist"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (d:Document {document_name: "Annual Employee Survey"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (d:Document {document_name: "Marketing Budget Proposal"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Stephanie White"}), (d:Document {document_name: "IT Security Best Practices"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Mark Fisher"}), (d:Document {document_name: "Sales Process Optimization Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (d:Document {document_name: "Legal Contracts Review"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (d:Document {document_name: "Customer Success Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (d:Document {document_name: "Q3 Financial Statement"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (d:Document {document_name: "Employee Performance Metrics"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Roberto Diaz"}), (d:Document {document_name: "IT Operations Manual"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "David Johnson"}), (d:Document {document_name: "Sales Lead Qualification Guide"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (d:Document {document_name: "Q3 Market Analysis"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (d:Document {document_name: "Internal Audit Findings"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Paul Martinez"}), (d:Document {document_name: "Quarterly Sales Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Nancy Taylor"}), (d:Document {document_name: "Account Management Handbook"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (d:Document {document_name: "IT Support Best Practices"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (d:Document {document_name: "Customer Complaint Resolution Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (d:Document {document_name: "Sales Incentive Program"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Mark Evans"}), (d:Document {document_name: "Marketing Collaboration Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Susan Gray"}), (d:Document {document_name: "Annual Employee Handbook"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Daniel Roberts"}), (d:Document {document_name: "Customer Feedback Response Guide"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (d:Document {document_name: "Quarterly IT Roadmap"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "George Harris"}), (d:Document {document_name: "Legal Risk Assessment Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Michael Adams"}), (d:Document {document_name: "Sales Strategy Review"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Raj Patel"}), (d:Document {document_name: "Client Acquisition Strategy"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (d:Document {document_name: "Company Culture Survey"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (d:Document {document_name: "Annual Marketing Plan"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Ethan Brooks"}), (d:Document {document_name: "Q4 Sales Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (d:Document {document_name: "Internal Controls Review"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (d:Document {document_name: "Employee Recognition Program"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Alicia Gomez"}), (d:Document {document_name: "New Client Proposal"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Roberto Diaz"}), (d:Document {document_name: "IT Infrastructure Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Linda Chen"}), (d:Document {document_name: "Q4 Financial Analysis"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Rachel Green"}), (d:Document {document_name: "Customer Service Guide"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Danielle Brown"}), (d:Document {document_name: "Legal Due Diligence Checklist"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Anthony Wright"}), (d:Document {document_name: "Marketing Campaign Brief"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Emily Davis"}), (d:Document {document_name: "Q1 Budget Allocation"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "David Johnson"}), (d:Document {document_name: "Sales Playbook"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Laura Peterson"}), (d:Document {document_name: "IT Training Manual"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Kevin Brown"}), (d:Document {document_name: "Performance Appraisal Guidelines"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Patricia Collins"}), (d:Document {document_name: "Employee Wellness Initiative"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Nancy Taylor"}), (d:Document {document_name: "Client Feedback Summary"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Susan Gray"}), (d:Document {document_name: "Legal Memorandum"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Ethan Brooks"}), (d:Document {document_name: "Sales Growth Metrics"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Amanda Lopez"}), (d:Document {document_name: "Marketing Tactics Review"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Daniel Roberts"}), (d:Document {document_name: "Quarterly Account Review"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "George Harris"}), (d:Document {document_name: "Legal Briefing Paper"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Eric Nelson"}), (d:Document {document_name: "IT Systems Audit"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Karen Lee"}), (d:Document {document_name: "Sales Team Handbook"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Raj Patel"}), (d:Document {document_name: "Customer Retention Guide"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Jessica Brown"}), (d:Document {document_name: "Company Policies Update"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Chris Taylor"}), (d:Document {document_name: "Market Opportunities Report"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Mark Fisher"}), (d:Document {document_name: "Sales Target Analysis"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Tom Wilson"}), (d:Document {document_name: "Q4 Revenue Breakdown"}) MERGE (p)-[:CREATED]->(d)
# Executing: MATCH (p:Person {name: "Samantha Green"}), (d:Document {document_name: "Legal Risk Mitigation Plan"}) MERGE (p)-[:CREATED]->(d)
# Successfully executed: cypher_statements/documents.txt
